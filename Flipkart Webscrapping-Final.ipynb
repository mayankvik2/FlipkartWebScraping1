# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = 'https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
flipkart_df= pd.DataFrame()
for page in range(1,3):
    page_url = base_url+str(page)
    print(page_url)
# Out:
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off1
# https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off2

# %%
r=requests.get(page_url)
soup1 = BeautifulSoup(r.text,"html5lib")
print(soup1.title)
# Out:
# <title>Mobile - Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
all_links = [link.get('href') for link in soup1.findAll(class_='_31qSD5', href=True)]
print(all_links[0])
# Out:
# /redmi-note-5-pro-black-64-gb/p/itmf2fc3xgmxnhpx?pid=MOBF28FTQPHUPX83&srno=s_1_1&otracker=search&lid=LSTMOBF28FTQPHUPX83H7IIOZ&fm=organic&iid=c826e48f-59b7-4686-bf90-5a344b3e1902.MOBF28FTQPHUPX83.SEARCH&qH=532c28d5412dd75b

# %%
head="https://www.flipkart.com"
URL=[]
for st in all_links:
    temp=head+st
    URL.append(temp)
print(URL[1])
# Out:
# https://www.flipkart.com/asus-zenfone-max-pro-m1-black-64-gb/p/itmf79gxwfs6yt8m?pid=MOBF4UQ9NSFFMH7Z&srno=s_1_2&otracker=search&lid=LSTMOBF4UQ9NSFFMH7ZYQWLHK&fm=organic&iid=d6369f7a-f848-4572-95e5-1b1eeebb8a4c.MOBF4UQ9NSFFMH7Z.SEARCH&qH=532c28d5412dd75b

# %%
r=requests.get(URL[1])
soup2 = BeautifulSoup(r.text,"html5lib")
print(soup2.title)
# Out:
# <title>Asus Zenfone Max Pro M1 (Black, 64 GB) Online at Best Price Only On Flipkart.com</title>

# %%
# Price
price=[]
for div in soup2.find_all(class_='_1vC4OE _3qQ9m1'):
    temp=div.text
    print(temp)
    temp=re.findall('\d+',temp)
    price.append(temp)
c_price=price[0][0]+price[0][1]
print(c_price)
    #Des.append(temp)
# Out:
# ₹14,999
# 14999

# %%
for div in soup2.find_all(class_='hGSR34 _2beYZw'):
                rating=div.text
print(rating)
# Out:
# 4.5 ★

# %%
# Description
Des=[]
for div in soup2.find_all(class_='_3YhLQA'):
    temp=div.text
    Des.append(temp)
    #print(temp)
#Des

# %%
Col=[]
for div in soup2.find_all(class_='_3-wDH3 col col-3-12'):
    temp=div.text
    Col.append(temp)
    #print(temp)
#Col

# %%
dictionary = dict(zip(Col,Des))
dictionary
# Out:
# {'In The Box': 'Handset, Adapter, USB Cable, Warranty Card, SIM Ejector, User Manual, Max-Box, Transparent Back Cover',
#  'Model Number': 'ZB601KL-4A005IN / ZB601KL-4A015IN',
#  'Model Name': 'Zenfone Max Pro M1',
#  'Color': 'Black',
#  'Browse Type': 'Smartphones',
#  'SIM Type': 'Dual Sim',
#  'Hybrid Sim Slot': 'No',
#  'Touchscreen': 'Yes',
#  'OTG Compatible': 'Yes',
#  'Sound Enhancements': '5 Magnet Speaker, 2nd Gen. NXP Smart AMP, Max Audio Box, Dual Microphone',
#  'Display Size': '15.21 cm (5.99 inch)',
#  'Resolution': '2160 x 1080 Pixels',
#  'Resolution Type': 'Full HD+',
#  'GPU': 'Adreno 509',
#  'Other Display Features': '2.5D Glass, 5.99inch Full View Display in 5.5-inch Compact Size, 83.7% Screen to Body Ratio, 2mm Slim Bezel, 18:9 Full View, Brightness in 450 nits, 1500:1 High Contrast Ratio, 85% NTSC Color Gamut',
#  'Operating System': 'Android Oreo 8',
#  'Processor Type': 'Qualcomm Snapdragon 636',
#  'Processor Core': 'Octa Core',
# ...

# %%
Offer=[]
for div in soup2.find_all(class_='_2ptBxu'):
    temp=div.text
    Offer.append(temp)
    #print(temp)
offer=Offer[0]
print(offer)
# Out:
# No cost EMI starting from ₹2,500/month

# %%
base_url = 'https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
## Mobile
base_url1 = 'https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.price_range.from%3D7000&p%5B%5D=facets.price_range.to%3DMax&p%5B%5D=facets.brand%255B%255D%3DSamsung&p%5B%5D=facets.brand%255B%255D%3DMicromax'
## Tablet
base_url2='https://www.flipkart.com/search?q=tablet&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
## Laptop
base_url13='https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.brand%255B%255D%3DDell&p%5B%5D=facets.brand%255B%255D%3DLenovo&p%5B%5D=facets.brand%255B%255D%3DAcer'

r=requests.get(base_url13)
soup1 = BeautifulSoup(r.text,"html5lib")
print(soup1.title)
# Out:
# <title>Laptop - Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
all_links = [link.get('href') for link in soup1.findAll(class_='_31qSD5', href=True)]
all_links[1]
# Out:
# '/acer-predator-helios-300-core-i5-8th-gen-8-gb-1-tb-hdd-128-gb-ssd-windows-10-home-4-graphics-ph315-51-ph315-51-51v7-gaming-laptop/p/itmf5nvpr5xsh2pg?pid=COMF5NVPQAZDMZFB&srno=s_1_2&otracker=search&lid=LSTCOMF5NVPQAZDMZFBBVX5AO&fm=organic&iid=50ae61b5-d10b-4766-89eb-61fa94ccc96a.COMF5NVPQAZDMZFB.SEARCH&qH=312f91285e048e09'

# %%
head="https://www.flipkart.com"
URL=[]
for st in all_links:
    temp=head+st
    URL.append(temp)
print(URL[1])
# Out:
# https://www.flipkart.com/acer-predator-helios-300-core-i5-8th-gen-8-gb-1-tb-hdd-128-gb-ssd-windows-10-home-4-graphics-ph315-51-ph315-51-51v7-gaming-laptop/p/itmf5nvpr5xsh2pg?pid=COMF5NVPQAZDMZFB&srno=s_1_2&otracker=search&lid=LSTCOMF5NVPQAZDMZFBBVX5AO&fm=organic&iid=50ae61b5-d10b-4766-89eb-61fa94ccc96a.COMF5NVPQAZDMZFB.SEARCH&qH=312f91285e048e09

# %% [markdown]
# # Main Coding

# %%
#Smartphone
base_url1 = 'https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.price_range.from%3D7000&p%5B%5D=facets.price_range.to%3DMax&p%5B%5D=facets.brand%255B%255D%3DSamsung&p%5B%5D=facets.brand%255B%255D%3DMicromax'
## Tablet
base_url2='https://www.flipkart.com/search?q=tablet&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
## Laptop
base_url13='https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.brand%255B%255D%3DDell&p%5B%5D=facets.brand%255B%255D%3DLenovo&p%5B%5D=facets.brand%255B%255D%3DAcer'

input1=input("Enter the electronic product you want to purchase:")
if input1=="smartphone":
    base_url=base_url1
elif input1=="tablet":
    base_url=base_url2
elif input1=="laptop":
    base_url=base_url13
else:
    print("Only Laptop Tablet Smartphone products are avilable")
# Out:
# Enter the electronic product you want to purchase:tablet

# %%
print(base_url)
# Out:
# https://www.flipkart.com/search?q=tablet&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off

# %%
final_df = pd.DataFrame()
naukri_df = pd.DataFrame()
#loop for each page
for page in range(1,3):
    page_url = base_url+str(page)
    r=requests.get(page_url)
    soup1 = BeautifulSoup(r.text,"html5lib")
    all_links = [link.get('href') for link in soup1.findAll(class_='_31qSD5', href=True)]
    head="https://www.flipkart.com"
    URL=[]
    for st in all_links:
        temp=head+st
        URL.append(temp)
    #Now inner loop for each url 
    for url in URL:
        r=requests.get(url)
        soup2 = BeautifulSoup(r.text,"html5lib")
        try:
            Offer=[]
            for div in soup2.find_all(class_='_2ptBxu'):
                temp=div.text
                Offer.append(temp)
            offer=Offer[0]
            #Price
            price=[]
            for div in soup2.find_all(class_='_1vC4OE _3qQ9m1'):
                temp=div.text
                temp=re.findall('\d+',temp)
                price.append(temp)
            c_price=price[0][0]+price[0][1]
            #Descrption
            # Description
            Des=[]
            for div in soup2.find_all(class_='_3YhLQA'):
                temp=div.text
                Des.append(temp)
            #Categories                
            Col=[]
            for div in soup2.find_all(class_='_3-wDH3 col col-3-12'):
                temp=div.text
                Col.append(temp)
            rating = soup2.find(attrs={'class': 'hGSR34 _2beYZw'})
            rating = rating.text.strip()     
            #Rating
            for div in soup2.find_all(class_='hGSR34 _2beYZw'):
                rating=div.text
            dictionary = dict(zip(Col,Des))
            dic_final=dict({'Price':c_price,'Offer':offer,'URL':url,'Rating':rating})
            dic_final.update(dictionary)
            
            final_df = final_df.append(dic_final,ignore_index=True)
            print(final_df) 

        except Exception as e:
            print("Incorrect url")
# Out:
#     2G   3G Audio Formats Supported Battery Capacity    Battery Type  \
# 0  Yes  Yes                     MP3         4800 mAh  Li-ion Polymer
#
#   Bluetooth Profiles Bluetooth Version  Browser           Color Connectivity  \
# 0                EDR              v4.1  Android  Luxurious Gold     Wi-Fi+4G
#
#        ...                                                     URL  \
# 0      ...       https://www.flipkart.com/honor-mediapad-t3-10-...
#
#               USB Video Formats Supported Video Playback Video Recording  \
# 0  Yes, Micro USB                     MP4            Yes             Yes
#
#   Voice Call   Warranty Warranty Service Type  \
# 0        Yes  12 Months              Carry In
#
#                             Warranty Summary Wi-fi Version
# 0  1 Year on Tablet, 6 Months on Accessories  802.11 b/g/n
#
# [1 rows x 58 columns]
#     2G   3G Audio Formats Supported Battery Capacity    Battery Type  \
# ...

# %%
#final_df.to_excel("FinalInspectflipkartlaptop2.xlsx")
writer = pd.ExcelWriter(r'FinalInspectflipkarttablet2.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
final_df.to_excel(writer)
writer.close()

# %% [markdown]
# ## RUN FOR MOBILE

# %%
final_df['Processor'] =  final_df['Processor Type'].fillna(final_df['Primary Clock Speed'])
#final_df['Processor']

# %%
mobiledata=final_df[['Model Name','Price','Offer','Operating System','Battery Capacity','Color','RAM','Internal Storage','Display Size','Resolution','Primary Camera','Secondary Camera','Processor','Sensors','URL']].copy()
mobiledata
#mobiledata.to_excel("flipkartmobile.xlsx")
# Out:
#            Model Name  Price                                   Offer  \
# 0          Galaxy On8  16990  No cost EMI starting from ₹1,888/month
# 1          Galaxy On6  13490  No cost EMI starting from ₹1,499/month
# 2          Galaxy On8  16990  No cost EMI starting from ₹1,888/month
# 3          Galaxy On8  16990  No cost EMI starting from ₹1,888/month
# 4          Galaxy On6  13490  No cost EMI starting from ₹1,499/month
# 5       Galaxy On Max  12490  No cost EMI starting from ₹2,082/month
# 6           Galaxy J8  17990  No cost EMI starting from ₹1,999/month
# 7           Galaxy J8  17990  No cost EMI starting from ₹1,999/month
# 8       Galaxy J3 Pro   7490  No cost EMI starting from ₹2,497/month
# 9       Galaxy On Max  12490  No cost EMI starting from ₹2,082/month
# 10          Galaxy J6  12990  No cost EMI starting from ₹2,165/month
# 11         Galaxy A6+  21990  No cost EMI starting from ₹2,444/month
# 12     Galaxy J2 2018   7690  No cost EMI starting from ₹2,564/month
# ...

# %%
writer = pd.ExcelWriter(r'Finalflipkartmobile.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
mobiledata.to_excel(writer)
writer.close()

# %% [markdown]
# ## RUN FOR TABLETS

# %%
final_df.to_excel('inspectflipkarttablet.xlsx')
#final_df['Processor'] = final_df['Processor Speed'].fillna('') + ' '+ final_df['Processor Type'].fillna('')
#final_df['Processor']

# %%
#tabletdata=final_df[['Model Name','Price','Offer','OS','Operating System Version','Battery Capacity','Color','RAM','Internal Storage','Display Size','Display Resolution','Primary Camera','Secondary Camera','Processor','Sensors']].copy()
tabletdata=final_df[['Model Name','Model Number','Price','Offer','Operating System','Battery Capacity','Color','RAM','Internal Storage','Display Size','Resolution','Primary Camera','Secondary Camera','Processor Type','Sensors','URL']].copy()
tabletdata
# Out:
#              Model Name    Model Number  Price  \
# 0        MediaPad T3 10         AGS-L09  16999
# 1                 A3 10   9026T-2EFKIN4  11999
# 2         Slide Enzo V8   slide enzo v8   6999
# 3           MediaPad T3         KOB-L09  13999
# 4           MediaPad T3         KOB-L09  11499
# 5     Yoga 3 (2 GB RAM)        Yt3-850m  15490
# 6          Galaxy Tab A  SM-T285NZWSINS   9490
# 7                Phab 2        PB2-650M   9999
# 8         A3 10 (VOLTE)           9026T   9999
# 9        iPad (6th Gen)       MR7F2HN/A  26900
# 10        Tab 4 10 Plus        TB-X704L  30990
# 11                A3 10            8080   6999
# 12        A3 10 (VOLTE)           9026T   9999
# 13         Galaxy Tab A  SM-T285NZKSINS   9490
# 14         Galaxy Tab A  SM-T595NZBAINS  29990
# 15              Tab 4 8        TB-8504X  13390
# 16            Brisk 4G2       Brisk 4G2   7999
# 17  Galaxy Tab A (2017)  SM-T385NZDAINS  17990
# 18  Galaxy Tab A (2017)  SM-T385NZKAINS  17990
# ...

# %%
writer = pd.ExcelWriter(r'Finalflipkarttablet.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
tabletdata.to_excel(writer)
writer.close()

# %% [markdown]
# ## RUN FOR LAPTOP

# %%
laptopdata=final_df[['Series','Model Number','Price','Offer','Operating System','Battery Backup','RAM','RAM Type','Graphic Processor','Processor Name','Processor Generation','Processor Brand','Web Camera','URL']].copy()
laptopdata
#laptopdata.to_excel('\',options={'strings_to_urls': False})
# Out:
#               Series     Model Number  Price  \
# 0        MacBook Air  MQD32HN/A A1466  61990
# 1        Ideapad 330        330-15IKB  43990
# 2        Ideapad 320     IP 320-15ISK  24490
# 3        Ideapad 320          IP 320S  34990
# 4        Ideapad 330        330-15IKB  47990
# 5   Inspiron 15 3000             3552  21990
# 6        Ideapad 330     IP 330-15AST  17990
# 7        Ideapad 130        130-14IKB  35990
# 8       Ideapad 320E        320-14ISK  23990
# 9   Inspiron 15 3000             3565  29490
# 10       Ideapad 330        330-15ARR  35990
# 11  Inspiron 14 3000             3467  27990
# 12          Inspiron             3467  27990
# 13          Yoga 510         Yoga 510  38990
# 14  Inspiron 14 3000             3467  28990
# 15          Inspiron             3552  19990
# 16  Inspiron 15 5000             5575  45990
# 17       Ideapad 330        330-15ARR  28490
# 18  Inspiron 13 5000             5370  44990
# 19       Ideapad 320     IP 320-14AST  21990
# ...

# %%
writer = pd.ExcelWriter(r'Finalflipkartlaptop.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
laptopdata.to_excel(writer)
writer.close()
